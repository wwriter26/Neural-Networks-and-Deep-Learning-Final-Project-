# %% [markdown]
# ### Benchmark file
# - This is the file where we actually track everything that we are measuring. ( Measure accuracy, latency, RAM usage, frames per second, and power draw). Saving everything to a structured CSV file.
