# %% [markdown]
# ### Compressing File
# - This file is going to wrap the trained data with its softmax layer, exports FP32 ONNX directly, FP16 via .half(), and INT8 using **onnxruntime.quantization.quantize_dynamic** on the FP32 ONNX and print the file sizes for all three.
